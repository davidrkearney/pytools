# %%
import pandas as pd
import numpy as np

 #df = pd.read_csv('df6.csv', error_bad_lines=False)

# %%
#df.describe() 
df.describe(include='all')
# Out:
#        account_id  amount_received  amount_expected  days_elapsed  \
# count       50000     5.000000e+04     5.000000e+04  50000.000000
# unique        159              NaN              NaN           NaN
# top        13N56X              NaN              NaN           NaN
# freq          898              NaN              NaN           NaN
# mean          NaN     2.263124e+05     2.995335e+05    305.933140
# std           NaN     2.453643e+05     3.106896e+05    273.633386
# min           NaN     0.000000e+00    -1.700000e+04      0.000000
# 25%           NaN     6.920000e+04     9.100000e+04    101.000000
# 50%           NaN     1.455000e+05     1.930000e+05    221.000000
# 75%           NaN     2.870000e+05     3.881000e+05    444.000000
# max           NaN     1.990000e+06     2.127000e+06   1526.000000
#
#         percent_loan_duration_elapsed  utilization_rate  percent_locked  \
# count                    50000.000000      48839.000000    48982.000000
# unique                            NaN               NaN             NaN
# top                               NaN               NaN             NaN
# freq                              NaN               NaN             NaN
# mean                         0.404494         84.673643       28.823188
# std                          0.462488        156.394464       25.122788
# min                          0.000000      -9071.430000        0.000000
# 25%                          0.108571         52.670000        6.400000
# 50%                          0.242196         83.110000       22.475000
# 75%                          0.517761        100.100000       48.587500
# max                          3.026087       8366.670000      100.000000
#
#         amount_received_in_last_30d_exc_deposit  days_locked_in_last_30d  \
# count                              20481.000000             20481.000000
# unique                                      NaN                      NaN
# top                                         NaN                      NaN
# freq                                        NaN                      NaN
# mean                               16806.709340                11.134124
# std                                26450.731619                10.915743
# min                              -232600.000000               -28.000000
# 25%                                 3000.000000                 1.000000
# 50%                                13500.000000                 7.000000
# 75%                                20000.000000                20.000000
# max                               400000.000000                30.000000
#
#         max_consecutive_days_locked  days_til_lockout payment_preference  \
# count                  50000.000000      50000.000000              49714
# unique                          NaN               NaN                  3
# top                             NaN               NaN              daily
# freq                            NaN               NaN              27251
# mean                      29.909220         -7.093660                NaN
# std                       42.449023         38.027286                NaN
# min                        0.000000       -656.000000                NaN
# 25%                        2.000000         -4.000000                NaN
# 50%                       10.000000          1.000000                NaN
# 75%                       40.000000          6.000000                NaN
# max                      655.000000        194.000000                NaN
#
#            kit_price    daily_rate  amount_remaining_interest_accrued_to_date
# count   5.000000e+04  50000.000000                               5.000000e+04
# unique           NaN           NaN                                        NaN
# top              NaN           NaN                                        NaN
# freq             NaN           NaN                                        NaN
# mean    7.281001e+05    883.445000                               4.735751e+05
# std     3.089613e+05    472.999003                               2.485134e+05
# min     2.300000e+05    500.000000                              -1.233200e+04
# 25%     6.120000e+05    600.000000                               3.732815e+05
# 50%     6.500000e+05    700.000000                               4.697545e+05
# 75%     7.500000e+05   1000.000000                               5.174102e+05
# max     2.390000e+06   3000.000000                               1.862170e+06

# %%
df.mean()
# Out:
# amount_received                              226312.440000
# amount_expected                              299533.536860
# days_elapsed                                    305.933140
# percent_loan_duration_elapsed                     0.404494
# utilization_rate                                 84.673643
# percent_locked                                   28.823188
# amount_received_in_last_30d_exc_deposit       16806.709340
# days_locked_in_last_30d                          11.134124
# max_consecutive_days_locked                      29.909220
# days_til_lockout                                 -7.093660
# kit_price                                    728100.060000
# daily_rate                                      883.445000
# amount_remaining_interest_accrued_to_date    473575.070820
# dtype: float64

# %%
df.std()
# Out:
# amount_received                              245364.305565
# amount_expected                              310689.609559
# days_elapsed                                    273.633386
# percent_loan_duration_elapsed                     0.462488
# utilization_rate                                156.394464
# percent_locked                                   25.122788
# amount_received_in_last_30d_exc_deposit       26450.731619
# days_locked_in_last_30d                          10.915743
# max_consecutive_days_locked                      42.449023
# days_til_lockout                                 38.027286
# kit_price                                    308961.290860
# daily_rate                                      472.999003
# amount_remaining_interest_accrued_to_date    248513.442819
# dtype: float64

# %%
df.median()
# Out:
# amount_received                              145500.000000
# amount_expected                              193000.000000
# days_elapsed                                    221.000000
# percent_loan_duration_elapsed                     0.242196
# utilization_rate                                 83.110000
# percent_locked                                   22.475000
# amount_received_in_last_30d_exc_deposit       13500.000000
# days_locked_in_last_30d                           7.000000
# max_consecutive_days_locked                      10.000000
# days_til_lockout                                  1.000000
# kit_price                                    650000.000000
# daily_rate                                      700.000000
# amount_remaining_interest_accrued_to_date    469754.500000
# dtype: float64

# %%
df.min()
# Out:
# account_id                                    112GS3
# amount_received                                    0
# amount_expected                               -17000
# days_elapsed                                       0
# percent_loan_duration_elapsed                      0
# utilization_rate                            -9071.43
# percent_locked                                     0
# amount_received_in_last_30d_exc_deposit      -232600
# days_locked_in_last_30d                          -28
# max_consecutive_days_locked                        0
# days_til_lockout                                -656
# kit_price                                     230000
# daily_rate                                       500
# amount_remaining_interest_accrued_to_date     -12332
# dtype: object

# %%
df.max()
# Out:
# account_id                                        1B4DP1
# amount_received                                 1.99e+06
# amount_expected                                2.127e+06
# days_elapsed                                        1526
# percent_loan_duration_elapsed                    3.02609
# utilization_rate                                 8366.67
# percent_locked                                       100
# amount_received_in_last_30d_exc_deposit           400000
# days_locked_in_last_30d                               30
# max_consecutive_days_locked                          655
# days_til_lockout                                     194
# kit_price                                       2.39e+06
# daily_rate                                          3000
# amount_remaining_interest_accrued_to_date    1.86217e+06
# dtype: object

# %%
df.count() 
#non-null value number for each feature
# Out:
# account_id                                   50000
# amount_received                              50000
# amount_expected                              50000
# days_elapsed                                 50000
# percent_loan_duration_elapsed                50000
# utilization_rate                             48839
# percent_locked                               48982
# amount_received_in_last_30d_exc_deposit      20481
# days_locked_in_last_30d                      20481
# max_consecutive_days_locked                  50000
# days_til_lockout                             50000
# payment_preference                           49714
# kit_price                                    50000
# daily_rate                                   50000
# amount_remaining_interest_accrued_to_date    50000
# dtype: int64

# %%
df.corr()
# Out:
#                                            amount_received  amount_expected  \
# amount_received                                   1.000000         0.895647
# amount_expected                                   0.895647         1.000000
# days_elapsed                                      0.725544         0.799065
# percent_loan_duration_elapsed                     0.761224         0.826026
# utilization_rate                                 -0.006741        -0.074265
# percent_locked                                   -0.143042         0.146764
# amount_received_in_last_30d_exc_deposit           0.413981         0.266860
# days_locked_in_last_30d                          -0.130952         0.078926
# max_consecutive_days_locked                       0.037196         0.327521
# days_til_lockout                                  0.056920        -0.155585
# kit_price                                         0.329819         0.289382
# daily_rate                                        0.541913         0.524356
# amount_remaining_interest_accrued_to_date        -0.104023        -0.074384
#
#                                            days_elapsed  \
# amount_received                                0.725544
# amount_expected                                0.799065
# days_elapsed                                   1.000000
# percent_loan_duration_elapsed                  0.938026
# utilization_rate                              -0.079457
# percent_locked                                 0.152739
# amount_received_in_last_30d_exc_deposit        0.006421
# days_locked_in_last_30d                        0.103147
# max_consecutive_days_locked                    0.385208
# days_til_lockout                              -0.137292
# kit_price                                     -0.102735
# daily_rate                                     0.121712
# amount_remaining_interest_accrued_to_date     -0.436989
#
#                                            percent_loan_duration_elapsed  \
# amount_received                                                 0.761224
# amount_expected                                                 0.826026
# days_elapsed                                                    0.938026
# percent_loan_duration_elapsed                                   1.000000
# utilization_rate                                               -0.062542
# percent_locked                                                  0.151356
# amount_received_in_last_30d_exc_deposit                         0.059747
# days_locked_in_last_30d                                         0.071757
# max_consecutive_days_locked                                     0.366533
# days_til_lockout                                               -0.122303
# kit_price                                                      -0.057420
# daily_rate                                                      0.246449
# amount_remaining_interest_accrued_to_date                      -0.399887
#
#                                            utilization_rate  percent_locked  \
# amount_received                                   -0.006741       -0.143042
# amount_expected                                   -0.074265        0.146764
# days_elapsed                                      -0.079457        0.152739
# percent_loan_duration_elapsed                     -0.062542        0.151356
# utilization_rate                                   1.000000       -0.229080
# percent_locked                                    -0.229080        1.000000
# amount_received_in_last_30d_exc_deposit            0.242250       -0.351551
# days_locked_in_last_30d                           -0.433493        0.786850
# max_consecutive_days_locked                       -0.151178        0.716160
# days_til_lockout                                   0.160545       -0.560517
# kit_price                                          0.011172       -0.036841
# daily_rate                                        -0.001804        0.019049
# amount_remaining_interest_accrued_to_date         -0.002110        0.083957
#
#                                            amount_received_in_last_30d_exc_deposit  \
# amount_received                                                           0.413981
# amount_expected                                                           0.266860
# days_elapsed                                                              0.006421
# percent_loan_duration_elapsed                                             0.059747
# utilization_rate                                                          0.242250
# percent_locked                                                           -0.351551
# amount_received_in_last_30d_exc_deposit                                   1.000000
# days_locked_in_last_30d                                                  -0.337368
# max_consecutive_days_locked                                              -0.288665
# days_til_lockout                                                          0.303096
# kit_price                                                                 0.500742
# daily_rate                                                                0.498962
# amount_remaining_interest_accrued_to_date                                 0.342393
#
#                                            days_locked_in_last_30d  \
# amount_received                                          -0.130952
# amount_expected                                           0.078926
# days_elapsed                                              0.103147
# percent_loan_duration_elapsed                             0.071757
# utilization_rate                                         -0.433493
# percent_locked                                            0.786850
# amount_received_in_last_30d_exc_deposit                  -0.337368
# days_locked_in_last_30d                                   1.000000
# max_consecutive_days_locked                               0.583604
# days_til_lockout                                         -0.658563
# kit_price                                                -0.083439
# daily_rate                                               -0.064564
# amount_remaining_interest_accrued_to_date                 0.067159
#
#                                            max_consecutive_days_locked  \
# amount_received                                               0.037196
# amount_expected                                               0.327521
# days_elapsed                                                  0.385208
# percent_loan_duration_elapsed                                 0.366533
# utilization_rate                                             -0.151178
# percent_locked                                                0.716160
# amount_received_in_last_30d_exc_deposit                      -0.288665
# days_locked_in_last_30d                                       0.583604
# max_consecutive_days_locked                                   1.000000
# days_til_lockout                                             -0.642138
# kit_price                                                    -0.037626
# daily_rate                                                    0.068178
# amount_remaining_interest_accrued_to_date                    -0.025567
#
#                                            days_til_lockout  kit_price  \
# amount_received                                    0.056920   0.329819
# amount_expected                                   -0.155585   0.289382
# days_elapsed                                      -0.137292  -0.102735
# percent_loan_duration_elapsed                     -0.122303  -0.057420
# utilization_rate                                   0.160545   0.011172
# percent_locked                                    -0.560517  -0.036841
# amount_received_in_last_30d_exc_deposit            0.303096   0.500742
# days_locked_in_last_30d                           -0.658563  -0.083439
# max_consecutive_days_locked                       -0.642138  -0.037626
# days_til_lockout                                   1.000000   0.013990
# kit_price                                          0.013990   1.000000
# daily_rate                                        -0.024307   0.910892
# amount_remaining_interest_accrued_to_date         -0.076307   0.849174
#
#                                            daily_rate  \
# amount_received                              0.541913
# amount_expected                              0.524356
# days_elapsed                                 0.121712
# percent_loan_duration_elapsed                0.246449
# utilization_rate                            -0.001804
# percent_locked                               0.019049
# amount_received_in_last_30d_exc_deposit      0.498962
# days_locked_in_last_30d                     -0.064564
# max_consecutive_days_locked                  0.068178
# days_til_lockout                            -0.024307
# kit_price                                    0.910892
# daily_rate                                   1.000000
# amount_remaining_interest_accrued_to_date    0.667408
#
#                                            amount_remaining_interest_accrued_to_date
# amount_received                                                            -0.104023
# amount_expected                                                            -0.074384
# days_elapsed                                                               -0.436989
# percent_loan_duration_elapsed                                              -0.399887
# utilization_rate                                                           -0.002110
# percent_locked                                                              0.083957
# amount_received_in_last_30d_exc_deposit                                     0.342393
# days_locked_in_last_30d                                                     0.067159
# max_consecutive_days_locked                                                -0.025567
# days_til_lockout                                                           -0.076307
# kit_price                                                                   0.849174
# daily_rate                                                                  0.667408
# amount_remaining_interest_accrued_to_date                                   1.000000

# %%
#Sum of null values in each feature
print(f"{df1.dtypes}\n")
print(f"Sum of null values in each feature:\n{35 * '-'}")
print(f"{df1.isnull().sum()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5af45ebccd70> in <module>
#       1 #Sum of null values in each feature
# ----> 2 print(f"{df1.dtypes}\n")
#       3 print(f"Sum of null values in each feature:\n{35 * '-'}")
#       4 print(f"{df1.isnull().sum()}")
#
# NameError: name 'df1' is not defined

# %%
df.head(10) # First n rows of the DataFrame
# Out:
#   account_id  amount_received  amount_expected  days_elapsed  \
# 0     1147G3         308100.0         728100.0           488
# 1     1147G3         308100.0         725400.0           486
# 2     1147G3         308100.0         722700.0           484
# 3     1147G3         308100.0         715950.0           479
# 4     1147G3         308100.0         714600.0           478
# 5     1147G3         308100.0         713250.0           477
# 6     1147G3         308100.0         711900.0           476
# 7     1147G3         308100.0         709200.0           474
# 8     1147G3         308100.0         706500.0           472
# 9     1147G3         308100.0         705150.0           471
#
#    percent_loan_duration_elapsed  utilization_rate  percent_locked  \
# 0                       0.903704             33.24         70.1271
# 1                       0.900000             33.38         70.0637
# 2                       0.896296             33.53         69.9360
# 3                       0.887037             33.89         69.6121
# 4                       0.885185             33.97         69.5464
# 5                       0.883333             34.04         69.4805
# 6                       0.881481             34.12         69.4143
# 7                       0.877778             34.27         69.2810
# 8                       0.874074             34.42         69.1466
# 9                       0.872222             34.50         69.0789
#
#    amount_received_in_last_30d_exc_deposit  days_locked_in_last_30d  \
# 0                                      0.0                     29.0
# 1                                      0.0                     30.0
# 2                                      0.0                     30.0
# 3                                      0.0                     30.0
# 4                                      0.0                     30.0
# 5                                      0.0                     30.0
# 6                                      0.0                     30.0
# 7                                      0.0                     30.0
# 8                                      NaN                      NaN
# 9                                      NaN                      NaN
#
#    max_consecutive_days_locked  days_til_lockout payment_preference  \
# 0                          179                 0              daily
# 1                          178              -178              daily
# 2                          176              -176              daily
# 3                          171              -171              daily
# 4                          170              -170              daily
# 5                          169              -169              daily
# 6                          168              -168              daily
# 7                          166              -166              daily
# 8                          164              -164              daily
# 9                          163              -163              daily
#
#    kit_price  daily_rate  amount_remaining_interest_accrued_to_date
# 0   729000.0      1350.0                                   516635.0
# 1   729000.0      1350.0                                   516504.0
# 2   729000.0      1350.0                                   516369.0
# 3   729000.0      1350.0                                   516014.0
# 4   729000.0      1350.0                                   515940.0
# 5   729000.0      1350.0                                   515865.0
# 6   729000.0      1350.0                                   515789.0
# 7   729000.0      1350.0                                   515634.0
# 8   729000.0      1350.0                                   515475.0
# 9   729000.0      1350.0                                   515394.0

# %%
df.tail(n) # Last n rows of the DataFrame
df.shape # Number of rows and columns
df.info() # Index, Datatype and Memory information
df.describe() # Summary statistics for numerical columns
s.value_counts(dropna=False) # View unique values and counts
df.apply(pd.Series.value_counts) # Unique values and counts for all columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-792701761d56> in <module>
# ----> 1 df.tail(n) # Last n rows of the DataFrame
#       2 df.shape # Number of rows and columns
#       3 df.info() # Index, Datatype and Memory information
#       4 df.describe() # Summary statistics for numerical columns
#       5 s.value_counts(dropna=False) # View unique values and counts
#
# NameError: name 'n' is not defined

# %%
#Unique values of a feature
df.Specific.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-fd04b6e2e06d> in <module>
#       1 #Unique values of a feature
# ----> 2 df.Specific.unique()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Specific'
